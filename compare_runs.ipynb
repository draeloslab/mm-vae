# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
osd_same = pd.read_csv('/home/rachel/Desktop/mm-vae results/multiregion_adbxd_cr_figureResults/multiregion_offsetcenters_seed10_trainosd50/osd_over_epochs.csv')
osd_offset = pd.read_csv('/home/rachel/Desktop/mm-vae results/multiregion_adbxd_cr_figureResults/multiregion_samecenters_seed10_trainosd50/osd_over_epochs.csv')

# %%
plt.plot(osd_same, label='Same centers')
plt.plot(osd_offset), label='Offset centers')
plt.title('OSD over epochs')
plt.legend()

# %%
mseloss_notrain = pd.read_csv('/home/rachel/Desktop/mm-vae results/multiregion_adbxd_cr_final/multiregion_testnotrainosd_seed15/mse_losses.csv')
mseloss_train = pd.read_csv('/home/rachel/Desktop/mm-vae results/multiregion_adbxd_cr_final/multiregion_testtrainosd_seed15/mse_losses.csv')

# %%
plt.plot(np.mean(mseloss_notrain, axis=1), label='train_osd=False')
plt.plot(np.mean(mseloss_train, axis=1), label='train_osd=True')
plt.title('Average matrix reconstruction loss')
plt.legend()

# %%
msecfmloss_notrain = pd.read_csv('/home/rachel/Desktop/mm-vae results/multiregion_adbxd_cr_final/multiregion_testnotrainosd_seed15/mse_cfm_losses.csv')
msecfmloss_train = pd.read_csv('/home/rachel/Desktop/mm-vae results/multiregion_adbxd_cr_final/multiregion_testtrainosd_seed15/mse_cfm_losses.csv')

# %%
plt.plot(np.mean(msecfmloss_notrain, axis=1), label='train_osd=False')
plt.plot(np.mean(msecfmloss_train, axis=1), label='train_osd=True')
plt.title('Average CFM reconstruction loss')
plt.legend()

# %%
ind_notrain = pd.read_csv('/home/rachel/Desktop/mm-vae results/multiregion_adbxd_cr_final/multiregion_testnotrainosd_seed15/individual_loss.csv')
ind_train = pd.read_csv('/home/rachel/Desktop/mm-vae results/multiregion_adbxd_cr_final/multiregion_testtrainosd_seed15/individual_loss.csv')

# %%
ind_notrain
# Out:
#     HC_lpx_z      HC_kls  PFC_lpx_z     PFC_kls
# 0   5.350328  736.734500   5.596991  734.032800
# 1   5.158837  715.711730   4.989883  708.851800
# 2   5.257972  663.081300   4.878136  656.803830
# 3   5.189777  574.631040   5.051069  572.577640
# 4   5.252435  519.308700   5.048965  502.590820
# ..       ...         ...        ...         ...
# 95  2.793090    3.001684   2.809639    3.413146
# 96  2.858728    3.341498   2.758447    4.487934
# 97  2.758967    3.337830   2.833235    3.338019
# 98  2.729538    2.532792   2.729257    2.757807
# 99  2.884054    2.693512   2.849075    3.156376
#
# [100 rows x 4 columns]

# %%
plt.plot(ind_notrain.iloc[:, [1, 3]].mean(axis=1), label='train_osd=False')
plt.plot(ind_train.iloc[:, [1, 3]].mean(axis=1), label='train_osd=True')
plt.title('Average KL loss')
plt.legend()
