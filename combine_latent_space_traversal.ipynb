# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Loading LV1

# %%
cum_difference_0_LV1 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/feature_analysis/cum_difference_0_LV1.csv', index_col=0).squeeze()
cum_difference_1_LV1 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/feature_analysis/cum_difference_1_LV1.csv', index_col=0).squeeze()
cum_difference_2_LV1 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/feature_analysis/cum_difference_2_LV1.csv', index_col=0).squeeze()
cum_difference_3_LV1 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/feature_analysis/cum_difference_3_LV1.csv', index_col=0).squeeze()
cum_difference_4_LV1 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/feature_analysis/cum_difference_4_LV1.csv', index_col=0).squeeze()

# %%
cum_difference_0_LV1
# Out:
# Generation            0.024742
# SurvDays              0.006395
# Diet_num              0.007315
# BW_BW                 0.019124
# Glu.F_Glucose         0.022695
# Echo_BPM              0.022569
# Echo_CardiacOutput    0.014868
# CBC_Hgb               0.022117
# Rotarod_Mean          0.018722
# AS_MeanLog            0.023655
# Wheel_AvgSpeedLFC     0.011768
# Wheel_AvgDistLFC      0.014226
# Grip_All              0.013010
# Frailty_FrailtyAdj    0.013584
# Name: 0, dtype: float64

# %%
LV1_comb = [cum_difference_0_LV1, cum_difference_1_LV1, cum_difference_2_LV1, cum_difference_3_LV1, cum_difference_4_LV1]
LV1_comb_df = pd.concat(LV1_comb, axis=1)
LV1_avg = LV1_comb_df.mean(axis=1)
LV1_avg.sort_values(ascending=False)
# Out:
# Generation            0.023386
# Glu.F_Glucose         0.016893
# CBC_Hgb               0.016001
# Echo_BPM              0.015912
# BW_BW                 0.015616
# Frailty_FrailtyAdj    0.015124
# AS_MeanLog            0.013961
# Rotarod_Mean          0.013016
# Echo_CardiacOutput    0.012215
# Grip_All              0.011761
# Wheel_AvgDistLFC      0.011170
# Diet_num              0.008165
# SurvDays              0.007507
# Wheel_AvgSpeedLFC     0.006784
# dtype: float64

# %% [markdown]
# ### Loading LV2

# %%
cum_difference_0_LV2 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/feature_analysis/cum_difference_0_LV2.csv', index_col=0).squeeze()
cum_difference_1_LV2 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/feature_analysis/cum_difference_1_LV2.csv', index_col=0).squeeze()
cum_difference_2_LV2 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/feature_analysis/cum_difference_2_LV2.csv', index_col=0).squeeze()
cum_difference_3_LV2 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/feature_analysis/cum_difference_3_LV2.csv', index_col=0).squeeze()
cum_difference_4_LV2 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/feature_analysis/cum_difference_4_LV2.csv', index_col=0).squeeze()

# %%
LV2_comb = [cum_difference_0_LV2, cum_difference_1_LV2, cum_difference_2_LV2, cum_difference_3_LV2, cum_difference_4_LV2]
LV2_comb_df = pd.concat(LV2_comb, axis=1)
LV2_avg = LV2_comb_df.mean(axis=1)
LV2_avg.sort_values(ascending=False)
# Out:
# SurvDays              0.027372
# Diet_num              0.023272
# Generation            0.017779
# CBC_Hgb               0.015739
# Frailty_FrailtyAdj    0.015201
# Echo_CardiacOutput    0.014984
# AS_MeanLog            0.014974
# Wheel_AvgSpeedLFC     0.013999
# Rotarod_Mean          0.013784
# Grip_All              0.013624
# Echo_BPM              0.013408
# Wheel_AvgDistLFC      0.012542
# BW_BW                 0.012055
# Glu.F_Glucose         0.011347
# dtype: float64

# %% [markdown]
# ### Loading LV3

# %%
cum_difference_0_LV3 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/feature_analysis/cum_difference_0_LV3.csv', index_col=0).squeeze()
cum_difference_1_LV3 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/feature_analysis/cum_difference_1_LV3.csv', index_col=0).squeeze()
cum_difference_2_LV3 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/feature_analysis/cum_difference_2_LV3.csv', index_col=0).squeeze()
cum_difference_3_LV3 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/feature_analysis/cum_difference_3_LV3.csv', index_col=0).squeeze()
cum_difference_4_LV3 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/feature_analysis/cum_difference_4_LV3.csv', index_col=0).squeeze()

# %%
LV3_comb = [cum_difference_0_LV3, cum_difference_1_LV3, cum_difference_2_LV3, cum_difference_3_LV3, cum_difference_4_LV3]
LV3_comb_df = pd.concat(LV3_comb, axis=1)
LV3_avg = LV3_comb_df.mean(axis=1)
LV3_avg.sort_values(ascending=False)
# Out:
# Generation            0.136970
# SurvDays              0.102144
# Grip_All              0.094753
# Wheel_AvgSpeedLFC     0.093940
# Wheel_AvgDistLFC      0.093478
# AS_MeanLog            0.079440
# Diet_num              0.075569
# CBC_Hgb               0.067860
# Frailty_FrailtyAdj    0.064545
# Echo_CardiacOutput    0.063551
# Rotarod_Mean          0.055717
# Echo_BPM              0.052570
# Glu.F_Glucose         0.041698
# BW_BW                 0.036858
# dtype: float64

# %% [markdown]
# ### Loading LV4

# %%
cum_difference_0_LV4 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/feature_analysis/cum_difference_0_LV4.csv', index_col=0).squeeze()
cum_difference_1_LV4 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/feature_analysis/cum_difference_1_LV4.csv', index_col=0).squeeze()
cum_difference_2_LV4 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/feature_analysis/cum_difference_2_LV4.csv', index_col=0).squeeze()
cum_difference_3_LV4 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/feature_analysis/cum_difference_3_LV4.csv', index_col=0).squeeze()
cum_difference_4_LV4 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/feature_analysis/cum_difference_4_LV4.csv', index_col=0).squeeze()

# %%
LV4_comb = [cum_difference_0_LV4, cum_difference_1_LV4, cum_difference_2_LV4, cum_difference_3_LV4, cum_difference_4_LV4]
LV4_comb_df = pd.concat(LV4_comb, axis=1)
LV4_avg = LV4_comb_df.mean(axis=1)
LV4_avg.sort_values(ascending=False)
# Out:
# Generation            0.059385
# SurvDays              0.032921
# Frailty_FrailtyAdj    0.027767
# Grip_All              0.027240
# Diet_num              0.026500
# Wheel_AvgDistLFC      0.025889
# AS_MeanLog            0.025749
# Wheel_AvgSpeedLFC     0.024251
# CBC_Hgb               0.021022
# Echo_BPM              0.019749
# Echo_CardiacOutput    0.018886
# Glu.F_Glucose         0.018723
# Rotarod_Mean          0.017460
# BW_BW                 0.016856
# dtype: float64

# %% [markdown]
# ### Loading LV5

# %%
cum_difference_0_LV5 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/feature_analysis/cum_difference_0_LV5.csv', index_col=0).squeeze()
cum_difference_1_LV5 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/feature_analysis/cum_difference_1_LV5.csv', index_col=0).squeeze()
cum_difference_2_LV5 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/feature_analysis/cum_difference_2_LV5.csv', index_col=0).squeeze()
cum_difference_3_LV5 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/feature_analysis/cum_difference_3_LV5.csv', index_col=0).squeeze()
cum_difference_4_LV5 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/feature_analysis/cum_difference_4_LV5.csv', index_col=0).squeeze()

# %%
LV5_comb = [cum_difference_0_LV5, cum_difference_1_LV5, cum_difference_2_LV5, cum_difference_3_LV5, cum_difference_4_LV5]
LV5_comb_df = pd.concat(LV5_comb, axis=1)
LV5_avg = LV5_comb_df.mean(axis=1)
LV5_avg.sort_values(ascending=False)
# Out:
# Generation            0.095409
# SurvDays              0.054431
# CBC_Hgb               0.049071
# Echo_BPM              0.048978
# Grip_All              0.046642
# Frailty_FrailtyAdj    0.046235
# Glu.F_Glucose         0.046057
# Echo_CardiacOutput    0.045965
# Wheel_AvgDistLFC      0.041201
# BW_BW                 0.038443
# AS_MeanLog            0.035729
# Rotarod_Mean          0.034684
# Diet_num              0.034374
# Wheel_AvgSpeedLFC     0.025648
# dtype: float64

# %% [markdown]
# ### Calculate weights by groups

# %%
avg_shap_values = [0.73164108, 0.17886729, 1.68632998, 2.01580303, 1.81895754]

# %%
weighted_differences = LV1_avg * avg_shap_values[0] + LV2_avg * avg_shap_values[1] + LV3_avg * avg_shap_values[2] + LV4_avg * avg_shap_values[3] + LV5_avg * avg_shap_values[4]

# %%
weighted_differences.sort_values(ascending=False)
# Out:
# Generation            0.544521
# SurvDays              0.348005
# Grip_All              0.310576
# Wheel_AvgDistLFC      0.295179
# AS_MeanLog            0.263750
# Frailty_FrailtyAdj    0.262703
# Wheel_AvgSpeedLFC     0.261419
# CBC_Hgb               0.260592
# Diet_num              0.253515
# Echo_CardiacOutput    0.240465
# Echo_BPM              0.231590
# Glu.F_Glucose         0.206224
# Rotarod_Mean          0.204229
# BW_BW                 0.179640
# dtype: float64

# %%
## DONT RUN
#weighted_differences_euclideandist = weighted_differences.sort_values(ascending=False)

# %%
weighted_differences_euclideandist
# Out:
# Grip_All              0.600900
# Wheel_AvgDistLFC      0.569287
# Frailty_FrailtyAdj    0.546035
# Generation            0.544521
# AS_MeanLog            0.532908
# Wheel_AvgSpeedLFC     0.517701
# CBC_Hgb               0.488659
# Echo_CardiacOutput    0.454609
# Echo_BPM              0.447414
# Rotarod_Mean          0.404819
# Glu.F_Glucose         0.389177
# BW_BW                 0.371085
# SurvDays              0.348005
# Diet_num              0.253515
# dtype: float64
