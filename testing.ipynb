# %%
# !pip install torch torchvision torchaudio
# !pip install numpy scikit-learn matplotlib seaborn pandas umap-learn

# %%
from __future__ import print_function
import argparse
import torch
import torch.utils.data
from torch import nn, optim
from torch.nn import functional as F
from torchvision import datasets, transforms
from torchvision.utils import save_image
import numpy as np
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from get_dataset_first_iter import _indices_for_labels
import umap
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 7
#       5 from torch import nn, optim
#       6 from torch.nn import functional as F
# ----> 7 from torchvision import datasets, transforms
#       8 from torchvision.utils import save_image
#       9 import numpy as np
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\__init__.py:10
#       7 # Don't re-order these, we need to load the _C extension (done when importing
#       8 # .extensions) before entering _meta_registrations.
#       9 from .extension import _HAS_OPS  # usort:skip
# ---> 10 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      12 try:
#      13     from .version import __version__  # noqa: F401
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torchvision\_meta_registrations.py:163
#     153     torch._check(
#     154         grad.dtype == rois.dtype,
#     155         lambda: (
#    (...)
#     158         ),
#     159     )
#     160     return grad.new_empty((batch_size, channels, height, width))
# --> 163 @torch.library.register_fake("torchvision::nms")
#     164 def meta_nms(dets, scores, iou_threshold):
#     165     torch._check(dets.dim() == 2, lambda: f"boxes should be a 2d tensor, got {dets.dim()}D")
#     166     torch._check(dets.size(1) == 4, lambda: f"boxes should have 4 elements in dimension 1, got {dets.size(1)}")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\library.py:828, in register(func)
#     796 def register_kernel(
#     797     op: _op_identifier,
#     798     device_types: device_types_t,
#    (...)
#     802     lib: Optional[Library] = None,
#     803 ):
#     804     """Register an implementation for a device type for this operator.
#     805
#     806     Some valid device_types are: "cpu", "cuda", "xla", "mps", "ipu", "xpu".
#     807     This API may be used as a decorator.
#     808
#     809     Args:
#     810         op (str | OpOverload): The operator to register an impl to.
#     811         device_types (None | str | Sequence[str]): The device_types to register an impl to.
#     812             If None, we will register to all device types -- please only use
#     813             this option if your implementation is truly device-type-agnostic.
#     814         func (Callable): The function to register as the implementation for
#     815             the given device types.
#     816         lib (Optional[Library]): If provided, the lifetime of this registration
#     817
#     818     Examples::
#     819         >>> # xdoctest: +REQUIRES(env:TORCH_DOCTEST_CUDA)
#     820         >>> import torch
#     821         >>> from torch import Tensor
#     822         >>> from torch.library import custom_op
#     823         >>> import numpy as np
#     824         >>>
#     825         >>> # Create a custom op that works on cpu
#     826         >>> @custom_op("mylib::numpy_sin", mutates_args=(), device_types="cpu")
#     827         >>> def numpy_sin(x: Tensor) -> Tensor:
# --> 828         >>>     x_np = x.numpy()
#     829         >>>     y_np = np.sin(x_np)
#     830         >>>     return torch.from_numpy(y_np)
#     831         >>>
#     832         >>> # Add implementations for the cuda device
#     833         >>> @torch.library.register_kernel("mylib::numpy_sin", "cuda")
#     834         >>> def _(x):
#     835         >>>     x_np = x.cpu().numpy()
#     836         >>>     y_np = np.sin(x_np)
#     837         >>>     return torch.from_numpy(y_np).to(device=x.device)
#     838         >>>
#     839         >>> x_cpu = torch.randn(3)
#     840         >>> x_cuda = x_cpu.cuda()
#     841         >>> assert torch.allclose(numpy_sin(x_cpu), x_cpu.sin())
#     842         >>> assert torch.allclose(numpy_sin(x_cuda), x_cuda.sin())
#     843
#     844     """
#     846     if not isinstance(
#     847         op, (str, torch._ops.OpOverload, torch._library.custom_ops.CustomOpDef)
#     848     ):
#     849         raise ValueError(
#     850             f"register_kernel({op}): got unexpected type for op: {type(op)}"
#     851         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\library.py:198, in _register_fake(self, op_name, fn, _stacklevel)
#     195     _library.utils.warn_deploy()
#     196     return
# --> 198 source = torch._library.utils.get_source(_stacklevel + 1)
#     199 frame = sys._getframe(_stacklevel)
#     200 caller_module = inspect.getmodule(frame)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\_library\fake_impl.py:31, in register(self, func, source)
#      27         return None
#      28     return self.kernels[-1]
#      30 @kernel.setter
# ---> 31 def kernel(self, value):
#      32     raise RuntimeError("Unable to directly set kernel.")
#      34 def register(
#      35     self, func: Callable, source: str, lib, *, allow_override=False
#      36 ) -> RegistrationHandle:
#
# RuntimeError: operator torchvision::nms does not exist

# %%
labels = [0,1,2,3,4,5]

#can only access dataset 1 at a time, easier to make a large dataloader. mayber theres a better way
full_train_dataset = datasets.MNIST('../data', train=True, download=True, transform=transforms.ToTensor())
tr_idx = _indices_for_labels(full_train_dataset, labels)
tr_subset = torch.utils.data.Subset(full_train_dataset, tr_idx)
#make a big DataLoader so you dont have to loop
tr_loader = torch.utils.data.DataLoader(tr_subset, batch_size=len(tr_subset), shuffle=False)

full_test_dataset =datasets.MNIST('../data', train=False, download=True, transform=transforms.ToTensor())
te_idx = _indices_for_labels(full_test_dataset, labels)
te_subset = torch.utils.data.Subset(full_test_dataset, te_idx)
#make a big DataLoader so you dont have to loop
te_loader = torch.utils.data.DataLoader(te_subset, batch_size=len(te_subset), shuffle=False)

for (data, label_data) in tr_loader:
    X = data
    y = label_data

# for (data, label_data) in te_loader:
#     X = data
#     y = label_data

# X, y = next(iter(loader))  # X: [N,1,28,28], y: [N]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 labels = [0,1,2,3,4,5]
#       3 #can only access dataset 1 at a time, easier to make a large dataloader. mayber theres a better way
# ----> 4 full_train_dataset = datasets.MNIST('../data', train=True, download=True, transform=transforms.ToTensor())
#       5 tr_idx = _indices_for_labels(full_train_dataset, labels)
#       6 tr_subset = torch.utils.data.Subset(full_train_dataset, tr_idx)
#
# NameError: name 'datasets' is not defined
