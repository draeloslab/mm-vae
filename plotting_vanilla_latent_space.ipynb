# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import numpy as np
import seaborn as sns

# %%
lv_epochs500 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/results_DIET/VanillaVAE/latent_variables_epoch500.csv')
lv_epochs1000 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/results_DIET/VanillaVAE/latent_variables_epoch1000.csv')
lv_epochs3000 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/results_DIET/VanillaVAE/latent_variables_epoch3000.csv')
lv_epochs7000 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/results_DIET/VanillaVAE/latent_variables_epoch5000.csv')
lv_epochs10000 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/results_DIET/VanillaVAE/latent_variables_epoch10000.csv')

# %%
lv_epochs500 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/results_DIET/VanillaVAE/latent_variables_epoch500.csv')
lv_epochs500
# Out:
#           LV1       LV2  labels   mouse_ids
# 0    0.306152 -1.182383       1  DO-20-1079
# 1   -0.234143  1.835025       2  DO-2D-4188
# 2    0.311117 -0.228417       0  DO-40-2072
# 3   -0.699416 -1.090183       2  DO-2D-4034
# 4   -0.084006  0.701995       3  DO-1D-3017
# ..        ...       ...     ...         ...
# 932  2.190333 -0.037338       1  DO-20-1062
# 933  0.682089 -1.109159       3  DO-1D-3070
# 934 -0.904987 -0.134295       3  DO-1D-3113
# 935 -0.061499  0.560602       1  DO-20-1017
# 936 -1.839004 -0.680083       1  DO-20-1029
#
# [937 rows x 4 columns]

# %%
# plotting at 500 epochs
plt.figure()
sns.scatterplot(data=lv_epochs500, x='LV1', y='LV2')
plt.figure()
sns.kdeplot(data=lv_epochs500, x='LV1', fill=True, bw_adjust=1, label='LV1')
sns.kdeplot(data=lv_epochs500, x='LV2', fill=True, bw_adjust=1, label='LV2')
plt.legend()
plt.xlabel('Latent Dimension Projection')
# Out:
# Text(0.5, 0, 'Latent Dimension Projection')

# %%
lv_epochs10000 = pd.read_csv('/Users/racheliritani/Desktop/AD Project/mm-vae/results_DIET/VanillaVAE/latent_variables_epoch10000.csv')
lv_epochs10000
# Out:
#           LV1       LV2  labels   mouse_ids
# 0    0.820099  0.667466       0  DO-40-2044
# 1   -2.489776  1.227131       2  DO-2D-4187
# 2    1.300144  0.520610       2  DO-2D-4097
# 3    0.271888  0.088385       0  DO-40-2157
# 4    0.277435  1.275114       4  DO-AL-0019
# ..        ...       ...     ...         ...
# 932  0.015366  0.519215       0  DO-40-2086
# 933 -0.529596  0.602389       4  DO-AL-0105
# 934 -0.358988 -0.829042       0  DO-40-2134
# 935 -1.081882  1.282177       2  DO-2D-4154
# 936  0.277369 -0.783570       4  DO-AL-0145
#
# [937 rows x 4 columns]

# %%
# plotting at 500 epochs
plt.figure()
sns.scatterplot(data=lv_epochs10000, x='LV1', y='LV2')
plt.figure()
sns.kdeplot(data=lv_epochs10000, x='LV1', fill=True, bw_adjust=1, label='LV1')
sns.kdeplot(data=lv_epochs10000, x='LV2', fill=True, bw_adjust=1, label='LV2')
plt.legend()
plt.xlabel('Latent Dimension Projection')
# Out:
# Text(0.5, 0, 'Latent Dimension Projection')

# %%
cfc = pd.read_csv('/Users/racheliritani/Desktop/AD Project/VAE-work/c-gmvae/cfc_data_filtered.csv')
cfc_latent_merged = pd.merge(lv_epochs10000, cfc, left_on='mouse_ids', right_on='Mouse.ID')
cfc_latent_merged
# Out:
#           LV1       LV2  labels   mouse_ids Diet    Mouse.ID  CFC.24mo.Average
# 0    0.820099  0.667466       0  DO-40-2044   40  DO-40-2044             60.47
# 1    1.300144  0.520610       2  DO-2D-4097   2D  DO-2D-4097             66.49
# 2    0.271888  0.088385       0  DO-40-2157   40  DO-40-2157             83.47
# 3    0.216439 -0.680385       3  DO-1D-3030   1D  DO-1D-3030             29.78
# 4    0.066055  0.067006       2  DO-2D-4057   2D  DO-2D-4057             25.39
# ..        ...       ...     ...         ...  ...         ...               ...
# 499 -1.303154 -0.628893       3  DO-1D-3089   1D  DO-1D-3089             76.40
# 500  0.015366  0.519215       0  DO-40-2086   40  DO-40-2086             29.42
# 501 -0.529596  0.602389       4  DO-AL-0105   AL  DO-AL-0105              4.93
# 502 -0.358988 -0.829042       0  DO-40-2134   40  DO-40-2134             24.04
# 503  0.277369 -0.783570       4  DO-AL-0145   AL  DO-AL-0145             67.78
#
# [504 rows x 7 columns]

# %%
sns.scatterplot(data=cfc_latent_merged, x='LV1', y='LV2', hue='CFC.24mo.Average')
plt.title('2D Latent space colored by CFC score')
# Out:
# Text(0.5, 1.0, '2D Latent space colored by CFC score')

# %%
ymaze_speed_data_cleaned = pd.read_csv('/Users/racheliritani/Desktop/AD Project/VAE-work/c-gmvae/ymaze_speed_data_cleaned.csv')
ymaze_speed_latent_merged = pd.merge(lv_epochs500, ymaze_speed_data_cleaned, left_on='mouse_ids', right_on='Mouse.ID')
sns.scatterplot(data=ymaze_speed_latent_merged, x='LV1', y='LV2', hue='Ymaze.MeanSpeed.10mo')
plt.title('2D Latent space colored by ymaze speed score')
# Out:
# Text(0.5, 1.0, '2D Latent space colored by ymaze speed score')

# %%
ymaze_distance_data_cleaned = pd.read_csv('/Users/racheliritani/Desktop/AD Project/VAE-work/c-gmvae/ymaze_distance_data_cleaned.csv')
ymaze_distance_latent_merged = pd.merge(lv_epochs500, ymaze_distance_data_cleaned, left_on='mouse_ids', right_on='Mouse.ID')
sns.scatterplot(data=ymaze_distance_latent_merged, x='LV1', y='LV2', hue='Ymaze.Distance.10mo')
plt.title('2D Latent space colored by ymaze distance score')
# Out:
# Text(0.5, 1.0, '2D Latent space colored by ymaze distance score')

# %%
ymaze_alt = pd.read_csv('/Users/racheliritani/Desktop/AD Project/VAE-work/c-gmvae/ymaze_alt_data_cleaned.csv')
ymaze_alt_latent_merged = pd.merge(lv_epochs500, ymaze_alt, left_on='mouse_ids', right_on='Mouse.ID')
sns.scatterplot(ymaze_alt_latent_merged, x='LV1', y='LV2', hue='SpontaneousAlternations.10mo')
plt.title('2D Latent space colored by num ymaze spontaneous alternations')
# Out:
# Text(0.5, 1.0, '2D Latent space colored by num ymaze spontaneous alternations')

# %%
ymaze_alt_latent_merged
# Out:
#           LV1       LV2  labels   mouse_ids Diet    Mouse.ID  \
# 0   -0.699416 -1.090183       2  DO-2D-4034   2D  DO-2D-4034
# 1    0.623453 -1.051826       1  DO-20-1025   20  DO-20-1025
# 2    0.644872 -0.909882       1  DO-20-1009   20  DO-20-1009
# 3   -1.083393  1.228331       0  DO-40-2160   40  DO-40-2160
# 4    1.355005  1.217770       0  DO-40-2167   40  DO-40-2167
# ..        ...       ...     ...         ...  ...         ...
# 499  0.768024 -0.022908       2  DO-2D-4039   2D  DO-2D-4039
# 500  0.555217 -0.060198       4  DO-AL-0176   AL  DO-AL-0176
# 501 -0.738924  0.307406       1  DO-20-1149   20  DO-20-1149
# 502  2.190333 -0.037338       1  DO-20-1062   20  DO-20-1062
# 503 -1.839004 -0.680083       1  DO-20-1029   20  DO-20-1029
#
#      SpontaneousAlternations.10mo
# 0                            15.0
# 1                            10.0
# 2                             8.0
# 3                             8.0
# 4                            22.0
# ...

# %%
color_map_diet = {
    '40': 'red', 
    '20': 'green', 
    '2D': 'purple', 
    '1D': 'blue', 
    'AL': 'orange'
}

# %%
sns.boxplot(x=ymaze_alt_latent_merged['Diet'], y=ymaze_alt_latent_merged['SpontaneousAlternations.10mo'], data=ymaze_alt_latent_merged, palette=color_map_diet)
plt.title('Distribution of Ymaze spontaneous alternations across diets')
# Out:
# /var/folders/9x/6ggst85x2311z107r2nwhbdc0000gn/T/ipykernel_3221/2302326714.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=ymaze_alt_latent_merged['Diet'], y=ymaze_alt_latent_merged['SpontaneousAlternations.10mo'], data=ymaze_alt_latent_merged, palette=color_map_diet)
# Text(0.5, 1.0, 'Distribution of Ymaze spontaneous alternations across diets')

# %% [markdown]
# ## 10 dim latent space results
